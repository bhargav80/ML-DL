# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
housing_prices = pd.read_csv("/content/HousingData.csv")
housing_prices.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# ##Preprocessing

# %%
null_values = housing_prices.isnull().sum()
null_values
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
housing_prices2 =housing_prices.dropna()

# %%
null_values = housing_prices2.isnull().sum()
null_values
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#Create X & Y values (features and labels)
X = housing_prices2.drop("MEDV",axis = 1)
Y = housing_prices2["MEDV"]

# %%
Y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 5    28.7
# Name: MEDV, dtype: float64

# %%
#Create training and test sets
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,
                              test_size = 0.2,random_state=42)
len(X),len(X_train),len(X_test)
# Out:
# (394, 315, 79)

# %% [markdown]
# ##Modelling

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(10),

                             tf.keras.layers.Dense(1)])

model.compile(loss = tf.keras.losses.mae,
                             optimizer = tf.keras.optimizers.Adam(learning_rate=0.10),
                             metrics = ["mae"])
model.fit(X_train,Y_train,epochs = 200,verbose = 0)

# %%
y_preds = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
 model.evaluate(X_test,Y_test)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 3.7192 - mae: 3.7192
# [3.7191736698150635, 3.7191736698150635]
